# %% [markdown]
# <a href="https://colab.research.google.com/github/hyeok9865/AI-python/blob/main/260403.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
answer=random.randint(1,100)

# %%
answer
# Out:
# 14

# %%
user=int(input("추측값을 입력하시오"))
# Out:
# 추측값을 입력하시오40

# %%
count=0
while user!= answer:
    if user < answer:
      print("더 큰 수를 입력하시오")
      count+=1
    else:
      print("더 작은 수를 입력하시오")
      count+=1
    user=int(input("추측값을 입력하시오"))
print("총 시도 횟수: ", count)
# Out:
# 더 작은 수를 입력하시오
# 추측값을 입력하시오30
# 더 작은 수를 입력하시오
# 추측값을 입력하시오20
# 더 작은 수를 입력하시오
# 추측값을 입력하시오15
# 더 작은 수를 입력하시오
# 추측값을 입력하시오14
# 총 시도 횟수:  4

# %%
for i in range(1,num+1)
